# %% [markdown]
# # Sanity Check
#
# Use the scripts from the project root first. This notebook is intentionally minimal so the repo stays lightweight.

# %%
from pathlib import Path
root = Path.cwd()
print(root)
print((root / 'data' / 'processed').exists())
